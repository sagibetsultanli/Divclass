# %% [markdown]
# <a href="https://colab.research.google.com/github/sagibetsultanli/Divclass/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.3
#exercise 1
dictionary = {
    "title":"pride_and_prejudice",
    "director" :"dontknow",
    "year": 2005,
    "genre":"love"
}
print(dictionary['title'])
dictionary["value"]= 8.5
print(dictionary)
dictionary["year"]= 2006
print(dictionary)
del dictionary["genre"]
print(dictionary)
# Out:
# pride_and_prejudice
# {'title': 'pride_and_prejudice', 'director': 'dontknow', 'year': 2005, 'genre': 'love', 'value': 8.5}
# {'title': 'pride_and_prejudice', 'director': 'dontknow', 'year': 2006, 'genre': 'love', 'value': 8.5}
# {'title': 'pride_and_prejudice', 'director': 'dontknow', 'year': 2006, 'value': 8.5}

# %%
#exercise 2
dictionary = {
    "title":"pride_and_prejudice",
    "director" :"dontknow",
    "year": 2005,
    "genre":"love"
}
print(dictionary.values())
print(dictionary.keys())
print(dictionary.get("producer","unknown"))
print("director" in dictionary)
# Out:
# dict_values(['pride_and_prejudice', 'dontknow', 2005, 'love'])
# dict_keys(['title', 'director', 'year', 'genre'])
# unknown
# True

# %%
#exercise 3
employees = {
    "alice":{"role":"developer","salary":5600},
    "bob":{"role:""designer","salary": 8900}
    }
# Out:
#   File "/tmp/ipython-input-1555392286.py", line 4
#     "bob":{"role:""designer","salary": 8900}
#                                      ^
# SyntaxError: invalid syntax
