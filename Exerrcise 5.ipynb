# %%
#EXERCISE 1.5 - 1
class Car:
    wheels = 4
    def drive(self):
        return "The car is driving"
    def stop(self):
        return "The car has stopped"
my_car = Car()
print(my_car.drive())
print(my_car.stop())
# Out:
# The car is driving
# The car has stopped

# %%
#exercise 2
class Car:
    
    def __init__(self,model,year):
        self.model = model
        self.year = year
    my_car = Car("Ford Mustang",2020)
    def describe(self):
        return f"This is a {self.year} {self.model}"
    print(my_car.describe())
# Out:
# This is a 2020 Ford Mustang

# %%
#exercise 3
class electric_car(Car):
    pass
    def __init__(self, model, year):
        super().__init__(model, year)
