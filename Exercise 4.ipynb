# %%
#1.4 advanced functions
#exercise 1
squarer = lambda x: x**2
squarer(8)
# Out:
# 64

# %%
#exercise 2
fruits = ['mango',"apple","banana","cherry"]
new_fruits = sorted(fruits, key = lambda fruit:fruit[-1])
print(new_fruits)   #neceeee
# Out:
# ['banana', 'apple', 'mango', 'cherry']

# %%
#exercise 3
a = lambda x,y:x*y
print(a(7,5))
# Out:
# 35

# %%
#exercise 4
celsius_temps = [0,10,20,30,40]
new = map(lambda c: c*9/5+32, celsius_temps)
list(new)
#4 ????
# Out:
# [32.0, 50.0, 68.0, 86.0, 104.0]

# %%
#exercise 5
numbers = [1,15,22,37,44,59,60,72]
new = filter(lambda x: x % 2== 0, numbers)
list(new)
#???
# Out:
# [22, 44, 60, 72]

# %%
#exercise 6
from functools import reduce
numbers = [1,2,3,4,5]
new = reduce(lambda x,y: x+y, numbers)
print(new)
# Out:
# 15

# %%
#LIST, DICTIONARY AND SET COMPREHENSIONS
#EXERCISE 7
new = []
for x in range(1,11):
  new.append(x**3)

print(new)
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %%
#exercise 8
words = ["Programming","is","fun","and","powerful"]
new = []
for x in words:
  if len(x)>5:
    new.append(x)
print(new)
# Out:
# ['Programming', 'powerful']

# %%
#exercise 10
numbers = [1,2,3,2,4,5,4,1]
new = set(numbers)
print(new)
# Out:
# {1, 2, 3, 4, 5}

# %%
#exercise 11
my_list = [10,20,30,40]
x = input((my_list[0]))
try:
  x = int
except:
  x = "int deyil"

# %%
#task1
x = 3
a = lambda x: x**3
print(x)
# Out:
# 3

# %%
new = []
for odd in range(1,16):
    if odd % 2 != 0:
        new.append(odd)
print(new)
# Out:
# [1, 3, 5, 7, 9, 11, 13, 15]

# %%
a = input(x)
try:
    erf daxil etme"
except: ValueError as e:
    "error oldu"
# Out:
#   Cell In[36], line 4
#     except: ValueError as e:
#                        ^
# SyntaxError: invalid syntax

# %%
#intermediate
filter(x lambda x% 4 == 0, x)

# %%
siyahi = ["alma","bali"]
meyve = {
    "":"alma"
    "siyahi[1]":"bali"
}
print(meyve)
# Out:
#   Cell In[45], line 4
#     "siyahi[1]":"bali"
#                ^
# SyntaxError: invalid syntax

# %%
raise
